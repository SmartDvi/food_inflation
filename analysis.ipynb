# %%
pip install pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\Moving_King\Documents\food_market\.venv\Scripts\python.exe: No module named pip

# %%
uv add pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\Moving_King\Documents\food_market\.venv\Scripts\python.exe: No module named uv

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'
